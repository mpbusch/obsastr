# %%
import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline

import matplotlib.pyplot as plt

import numpy as np

# %%
def angularSizeChart():
    
    # read in data from spread sheet
    
    # set up figure
    f, ax = plt.subplots(1,figsize=(16,10))
    f.set_facecolor('w')
    f.canvas.set_window_title("Angular Sizes")
    
    ax.set_title("Angular Sizes",fontsize=20,fontweight='bold')
    ax.set_xscale("log")
    ax.set_xlabel("Angular Size (unit?)")
    
    # plot
    
    
    plt.show()

# %%
angularSizeChart()
